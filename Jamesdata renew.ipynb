# %%
import yfinance as yf
import pandas as pd # data manipulation
import matplotlib.pyplot as plt # main visualization module: matplotlib's pyplot
import seaborn as sns # visualizations' top level. seaborn's style on top of matplotlib
sns.set()
import numpy as np
import datetime
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates

# %%
name_stock = input()
# Out:
# INTC

# %%
A = yf.Ticker(name_stock)
print(A.info.keys())
# Out:
# dict_keys(['zip', 'sector', 'fullTimeEmployees', 'longBusinessSummary', 'city', 'phone', 'state', 'country', 'companyOfficers', 'website', 'maxAge', 'address1', 'industry', 'previousClose', 'regularMarketOpen', 'twoHundredDayAverage', 'trailingAnnualDividendYield', 'payoutRatio', 'volume24Hr', 'regularMarketDayHigh', 'navPrice', 'averageDailyVolume10Day', 'totalAssets', 'regularMarketPreviousClose', 'fiftyDayAverage', 'trailingAnnualDividendRate', 'open', 'toCurrency', 'averageVolume10days', 'expireDate', 'yield', 'algorithm', 'dividendRate', 'exDividendDate', 'beta', 'circulatingSupply', 'startDate', 'regularMarketDayLow', 'priceHint', 'currency', 'trailingPE', 'regularMarketVolume', 'lastMarket', 'maxSupply', 'openInterest', 'marketCap', 'volumeAllCurrencies', 'strikePrice', 'averageVolume', 'priceToSalesTrailing12Months', 'dayLow', 'ask', 'ytdReturn', 'askSize', 'volume', 'fiftyTwoWeekHigh', 'forwardPE', 'fromCurrency', 'fiveYearAvgDividendYield', 'fiftyTwoWeekLow', 'bid', 'tradea
# ...

# %%
B = A.info
B
# Out:
# {'zip': '95054-1549',
#  'sector': 'Technology',
#  'fullTimeEmployees': 110600,
# ...

# %%
F= A.cashflow
F
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
B = A.info
B = [B['shortName'], B['symbol'], B['previousClose'],B['marketCap'],B['fiftyTwoWeekLow'], B['forwardPE'],  B['sharesShort'], B['priceToBook'], B['profitMargins'],B['shortRatio'], B['lastSplitFactor']]
B
# Out:
# ['Intel Corporation',
#  'INTC',
#  54.01,
#  223503302656,
#  43.61,
#  12.058823,
#  50068953,
#  2.8005464,
#  0.23933001,
#  1.62,
#  '2:1']

# %%
B
# Out:
# ['Intel Corporation',
#  'INTC',
#  54.01,
#  223503302656,
#  43.61,
#  12.058823,
#  50068953,
#  2.8005464,
#  1.62,
#  '2:1']

# %%
type(B)
# Out:
# list

# %%
from pandas import DataFrame

# %%
daf = DataFrame(B,columns=['Data'], index=['Name','Symbol','Previous Close','Market Capitalization','Fifty Two Week Low','PE',  'Shares Short', 'P/B', 'Profit Margin','Short Ratio', 'Last Split'])

# %%
daf
# Out:
#                                     Data
# Name                   Intel Corporation
# Symbol                              INTC
# Previous Close                     54.01
# Market Capitalization       223503302656
# Fifty Two Week Low                 43.61
# PE                             12.058823
# Shares Short                    50068953
# P/B                             2.800546
# Profit Margin                    0.23933
# Short Ratio                         1.62
# Last Split                           2:1

# %%
def color(value):
    color = 'Green'
    return 'color: %s' % color

# %%
#def color(value):
 #    if type(value) == 'int':
  #          color = 'Green'
   #  elif type(value) == 'str':
    #    color = 'red'
     #else:
      #  color = 'black'
#
 #    return 'color: %s' % color

# %%
daf.style.applymap(color, subset=['Data'])
# Out:
# <style  type="text/css" >
# #T_10f2f_row0_col0,#T_10f2f_row1_col0,#T_10f2f_row2_col0,#T_10f2f_row3_col0,#T_10f2f_row4_col0,#T_10f2f_row5_col0,#T_10f2f_row6_col0,#T_10f2f_row7_col0,#T_10f2f_row8_col0,#T_10f2f_row9_col0,#T_10f2f_row10_col0{
#             color:  Green;
#         }</style><table id="T_10f2f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Data</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_10f2f_level0_row0" class="row_heading level0 row0" >Sector</th>
#                         <td id="T_10f2f_row0_col0" class="data row0 col0" >Intel Corporation</td>
#             </tr>
#             <tr>
#                         <th id="T_10f2f_level0_row1" class="row_heading level0 row1" >Symbol</th>
#                         <td id="T_10f2f_row1_col0" class="data row1 col0" >INTC</td>
#             </tr>
#             <tr>
# ...

# %%
daf.head(10).style.set_properties(**{'background-color': 'black',                                                   
                                    'color': 'lawngreen',                       
                                    'border-color': 'white'})
# Out:
# <style  type="text/css" >
# #T_b05c2_row0_col0,#T_b05c2_row1_col0,#T_b05c2_row2_col0,#T_b05c2_row3_col0,#T_b05c2_row4_col0,#T_b05c2_row5_col0,#T_b05c2_row6_col0,#T_b05c2_row7_col0,#T_b05c2_row8_col0,#T_b05c2_row9_col0{
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }</style><table id="T_b05c2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Data</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b05c2_level0_row0" class="row_heading level0 row0" >Sector</th>
#                         <td id="T_b05c2_row0_col0" class="data row0 col0" >Intel Corporation</td>
#             </tr>
#             <tr>
#                         <th id="T_b05c2_level0_row1" class="row_heading level0 row1" >Symbol</th>
#                         <td id="T_b05c2_row1_col0" class="data row1 col0" >INTC</td>
#             </tr>
#             <tr>
# ...

# %%
type(B)
# Out:
# list

# %%
column_names = ["Name","Symbol","Previous Close", "Market Capitalization", "Fifty Two Weeks Low","PE",  "Shares Short", "P/B", "Profit Margins", "Short Ratio", "Last Split"]

df = pd.DataFrame(columns = column_names)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Name, Symbol, Previous Close, Market Capitalization, Fifty Two Weeks Low, PE, Shares Short, P/B, Profit Margins, Short Ratio, Last Split]
# Index: []

# %%
new = pd.Series(B, index = df.columns)
df = df.append(new, ignore_index=True)
df
# Out:
#                 Name Symbol  Previous Close Market Capitalization  \
# 0  Intel Corporation   INTC           54.01          223503302656
#
#    Fifty Two Weeks Low         PE Shares Short       P/B  Profit Margins  \
# 0                43.61  12.058823     50068953  2.800546         0.23933
#
#    Short Ratio Last Split
# 0         1.62        2:1

# %%
df.head(11).style.format({"Previous Close": "${:20,.2f}",
                          "Market Capitalization": "{0:,}",
                          "Fifty Two Weeks Low": "${:20,.2f}",
                          "PE": "{:20,.2f}%",
                          "Shares Short": "{0:,}",
                          "P/B": "{:20,.2f}",
                          "Profit Margins": "{:20,.2f}%",
                          "Short Ratio": "{:20,.2f}"
                       })\
.set_properties(**{'background-color': 'black',                                                   
                                    'color': 'lawngreen',                       
                                    'border-color': 'white'})\
.hide_index()
# Out:
# <style  type="text/css" >
# #T_48a19_row0_col0,#T_48a19_row0_col1,#T_48a19_row0_col2,#T_48a19_row0_col3,#T_48a19_row0_col4,#T_48a19_row0_col5,#T_48a19_row0_col6,#T_48a19_row0_col7,#T_48a19_row0_col8,#T_48a19_row0_col9,#T_48a19_row0_col10{
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
# ...

# %%
dataset2 = A.history(period ='5d', interval = '60m')
print(dataset2)
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2021-05-10 09:30:00-04:00  57.146500  57.230000  56.290001  56.340000
# 2021-05-10 10:30:00-04:00  56.330002  56.430000  56.174999  56.415001
# 2021-05-10 11:30:00-04:00  56.415001  56.584999  56.360001  56.480000
# 2021-05-10 12:30:00-04:00  56.485001  56.500000  56.349998  56.440102
# 2021-05-10 13:30:00-04:00  56.439999  56.470001  56.009998  56.060001
# 2021-05-10 14:30:00-04:00  56.060001  56.189999  55.965000  56.115002
# 2021-05-10 15:30:00-04:00  56.115002  56.209999  55.880001  55.980000
# 2021-05-11 09:30:00-04:00  55.049999  55.630001  54.700001  54.880001
# 2021-05-11 10:30:00-04:00  54.889999  54.919998  54.299999  54.825001
# 2021-05-11 11:30:00-04:00  54.825001  55.049999  54.709999  54.865002
# 2021-05-11 12:30:00-04:00  54.860001  55.230000  54.709999  55.185001
# 2021-05-11 13:30:00-04:00  55.189999  55.369999  55.090000  55.320000
# ...

# %%
dataset
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2021-05-14 09:30:00-04:00  54.604599  55.049999  54.299999  55.000000
# 2021-05-14 10:30:00-04:00  55.000000  55.314999  54.990002  55.299999
# 2021-05-14 11:30:00-04:00  55.299999  55.529999  55.189999  55.503201
# 2021-05-14 12:30:00-04:00  55.500000  55.610001  55.450001  55.580002
# 2021-05-14 13:30:00-04:00  55.584999  55.709999  55.500000  55.700001
# 2021-05-14 14:30:00-04:00  55.709999  55.846699  55.570000  55.629902
# 2021-05-14 15:30:00-04:00  55.625000  55.639999  55.290001  55.330002
#
#                             Volume  Dividends  Stock Splits
# Datetime
# 2021-05-14 09:30:00-04:00  4967846          0             0
# 2021-05-14 10:30:00-04:00  4877173          0             0
# 2021-05-14 11:30:00-04:00  2417017          0             0
# 2021-05-14 12:30:00-04:00  1815316          0             0
# 2021-05-14 13:30:00-04:00  1770228          0             0
# ...

# %%
dataset3 = A.history(period ='1mo', interval = '60m')
dataset4 = A.history(period ='6mo', interval = '60m')
dataset5 = A.history(period ='1y', interval = '60m')
dataset3
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2021-04-08 09:30:00-04:00  676.000000  687.270020  671.717407  685.919983
# 2021-04-08 10:30:00-04:00  686.099976  689.549927  681.510010  684.580017
# 2021-04-08 11:30:00-04:00  684.599976  688.734680  683.799988  687.536194
# 2021-04-08 12:30:00-04:00  687.570007  688.000000  681.140015  681.643494
# 2021-04-08 13:30:00-04:00  681.780029  683.880005  679.277771  681.955017
# ...                               ...         ...         ...         ...
# 2021-05-07 11:30:00-04:00  677.460022  678.179871  670.588379  671.190002
# 2021-05-07 12:30:00-04:00  671.224976  674.549927  667.670471  668.239990
# 2021-05-07 13:30:00-04:00  668.289978  670.869995  664.099976  670.378174
# 2021-05-07 14:30:00-04:00  670.479980  674.440613  665.300110  671.219971
# 2021-05-07 15:30:00-04:00  671.400024  673.000000  669.010010  672.369995
#
#                             Volume  Dividends  Stock Splits
# ...

# %%
dataset2['Close']
# Out:
# Datetime
# 2021-05-03 09:30:00-04:00    696.000916
# 2021-05-03 10:30:00-04:00    684.770020
# 2021-05-03 11:30:00-04:00    688.330017
# 2021-05-03 12:30:00-04:00    682.760010
# 2021-05-03 13:30:00-04:00    683.270020
# 2021-05-03 14:30:00-04:00    686.755310
# 2021-05-03 15:30:00-04:00    684.789978
# 2021-05-04 09:30:00-04:00    671.700012
# 2021-05-04 10:30:00-04:00    664.309998
# 2021-05-04 11:30:00-04:00    665.000000
# 2021-05-04 12:30:00-04:00    666.116821
# 2021-05-04 13:30:00-04:00    664.733521
# 2021-05-04 14:30:00-04:00    665.991516
# 2021-05-04 15:30:00-04:00    674.179993
# 2021-05-05 09:30:00-04:00    671.479980
# 2021-05-05 10:30:00-04:00    675.520020
# 2021-05-05 11:30:00-04:00    673.210022
# 2021-05-05 12:30:00-04:00    673.785217
# 2021-05-05 13:30:00-04:00    673.080017
# 2021-05-05 14:30:00-04:00    669.049988
# 2021-05-05 15:30:00-04:00    671.280029
# 2021-05-06 09:30:00-04:00    659.035828
# 2021-05-06 10:30:00-04:00    658.869873
# ...

# %%
plt.style.use('dark_background')
plt.subplots(figsize=(16,8))
plt.plot(dataset5['Close'], label=name_stock, linewidth = '4', color = 'b')
plt.xlabel("Datetime")
plt.ylabel("Price")
plt.legend()
plt.title('Stock Price over Time')
plt.show()

# %%
plt.style.use('dark_background')
plt.subplots(figsize=(16,8))
plt.plot(dataset['Close'], label=name_stock, linewidth = '4', color = 'b')
plt.xlabel("Datetime")
plt.ylabel("Price")
plt.legend()
plt.title('Stock Price over Time')
plt.show()

# %%
plt.style.use('dark_background')
plt.subplots(figsize=(16,8))
plt.plot(dataset4['Close'], label=name_stock, linewidth = '4', color = 'b')
plt.xlabel("Datetime")
plt.ylabel("Price")
plt.legend()
plt.title('Stock Price over Time')
plt.show()

# %%
plt.style.use('dark_background')
plt.subplots(figsize=(16,8))
plt.plot(dataset3['Close'], label=name_stock, linewidth = '4', color = 'b')
plt.xlabel("Datetime")
plt.ylabel("Price")
plt.legend()
plt.title('Stock Price over Time')
plt.show()

# %%
plt.style.use('dark_background')
plt.subplots(figsize=(16,8))
plt.plot(dataset2['Close'], label=name_stock, linewidth = '4', color = 'b')
plt.xlabel("Datetime")
plt.ylabel("Price")
plt.legend()
plt.title('Stock Price over Time')
plt.show()

# %%
dataset.head()
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2021-05-07 09:30:00-04:00  662.520020  679.710022  660.219971  675.359985
# 2021-05-07 10:30:00-04:00  675.489990  690.000000  675.080017  677.330872
# 2021-05-07 11:30:00-04:00  677.460022  678.179871  670.588379  671.190002
# 2021-05-07 12:30:00-04:00  671.224976  674.549927  667.670471  668.239990
# 2021-05-07 13:30:00-04:00  668.289978  670.869995  664.099976  670.378174
#
#                             Volume  Dividends  Stock Splits
# Datetime
# 2021-05-07 09:30:00-04:00  6921055          0             0
# 2021-05-07 10:30:00-04:00  3906807          0             0
# 2021-05-07 11:30:00-04:00  2317330          0             0
# 2021-05-07 12:30:00-04:00  2152021          0             0
# 2021-05-07 13:30:00-04:00  2381961          0             0

# %%
dataset.isna().any()
# Out:
# Open            False
# High            False
# Low             False
# Close           False
# Volume          False
# Dividends       False
# Stock Splits    False
# dtype: bool

# %%
dataset.info()
dataset = dataset.drop(columns=['Dividends', 'Stock Splits'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7 entries, 2021-05-07 09:30:00-04:00 to 2021-05-07 15:30:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          7 non-null      float64
#  1   High          7 non-null      float64
#  2   Low           7 non-null      float64
#  3   Close         7 non-null      float64
#  4   Volume        7 non-null      int64
#  5   Dividends     7 non-null      int64
#  6   Stock Splits  7 non-null      int64
# dtypes: float64(4), int64(3)
# memory usage: 448.0 bytes

# %%
dataset['Open'].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
dataset.rolling(7).mean().head(20)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2021-05-07 09:30:00-04:00         NaN         NaN         NaN         NaN
# 2021-05-07 10:30:00-04:00         NaN         NaN         NaN         NaN
# 2021-05-07 11:30:00-04:00         NaN         NaN         NaN         NaN
# 2021-05-07 12:30:00-04:00         NaN         NaN         NaN         NaN
# 2021-05-07 13:30:00-04:00         NaN         NaN         NaN         NaN
# 2021-05-07 14:30:00-04:00         NaN         NaN         NaN         NaN
# 2021-05-07 15:30:00-04:00  670.980713  677.250061  667.424133  672.298427
#
#                                  Volume
# Datetime
# 2021-05-07 09:30:00-04:00           NaN
# 2021-05-07 10:30:00-04:00           NaN
# 2021-05-07 11:30:00-04:00           NaN
# 2021-05-07 12:30:00-04:00           NaN
# 2021-05-07 13:30:00-04:00           NaN
# 2021-05-07 14:30:00-04:00           NaN
# 2021-05-07 15:30:00-04:00  3.223137e+06

# %%
dataset['Open'].plot(figsize=(16,6))
dataset.rolling(window=30).mean()['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
dataset['Close: 30 Day Mean'] = dataset['Close'].rolling(window=30).mean()
dataset[['Close', 'Close: 30 Day Mean']].plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
dataset['Close'].expanding(min_periods=1).mean().plot(figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
training_set=dataset['Open']
training_set=pd.DataFrame(training_set)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))

# %%
training_set_scaled = sc.fit_transform(training_set)

# %%
x_train = []
y_train = []
for i in range(60, len(training_set_scaled)):
    x_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
regressor = Sequential()

# %%
#first LSTM layer
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1],1)))
regressor.add(Dropout(0,2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0,2))

# %%
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0,2))

# %%
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0,2))

# %%
regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
regressor.fit(x_train, y_train, epochs = 100, batch_size=32)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-8d06ed0a11a1> in <module>
# ----> 1 regressor.fit(x_train, y_train, epochs = 100, batch_size=32)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
# ...
